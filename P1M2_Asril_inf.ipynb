# %% [markdown]
# # Introduction

# %% [markdown]
# Nama : Muhammad Asril Hanif
#
# Batch : RMT-034

# %% [markdown]
# # Model Inference

# %%
# Libraries yang digunakan untuk inference
import pandas as pd
import pickle

# %% [markdown]
# Import Libary yang dibutuhkan untuk inferencing

# %%
# Load file pickle
with open("best_model.pkl","rb") as file_1:
    best_model = pickle.load(file_1)

# %% [markdown]
# Import model machine learning yang sudah dibuat

# %%
data = {
    'Age':[20,24,35,46],
    'Location':['Rural','Suburban','Rural','Urban'],
    'DietType':['Mostly Animal-Based','Mostly Plant-Based','Mostly Plant-Based', 'Balanced'],
    'LocalFoodFrequency':['Often','Sometimes','Sometimes','Rarely'],
    'TransportationMode':['Car','Bike','Walk','Public Transit'],
    'EnergySource':['Mixed','Renewable','Renewable','Non-Renewable'],
    'HomeType':['House','House','House','Apartment'],
    'HomeSize':[300,456,900,3000],
    'ClothingFrequency':['Rarely','Often','Sometimes','Rarely'],
    'SustainableBrands':[False,True,False,False],
    'EnvironmentalAwareness':[2,5,5,4],
    'CommunityInvolvement':['High','Moderate','Low','High'],
    'MonthlyElectricityConsumption':[30,70,200,45],
    'MonthlyWaterConsumption':[4000,1500,3000,700],
    'Gender':['Female','Male','Female','Female'],
    'UsingPlasticProducts':['Rarely','Often','Sometimes','Rarely'],
    'DisposalMethods':['Composting','Landfill','Composting','Recycling'],
    'PhysicalActivities':['High','Moderate','High','High']
}

data = pd.DataFrame(data)
data
# Out:
#    Age  Location             DietType LocalFoodFrequency TransportationMode  \
# 0   20     Rural  Mostly Animal-Based              Often                Car
# 1   24  Suburban   Mostly Plant-Based          Sometimes               Bike
# 2   35     Rural   Mostly Plant-Based          Sometimes               Walk
# 3   46     Urban             Balanced             Rarely     Public Transit
#
#     EnergySource   HomeType  HomeSize ClothingFrequency  SustainableBrands  \
# 0          Mixed      House       300            Rarely              False
# 1      Renewable      House       456             Often               True
# 2      Renewable      House       900         Sometimes              False
# 3  Non-Renewable  Apartment      3000            Rarely              False
#
#    EnvironmentalAwareness CommunityInvolvement  MonthlyElectricityConsumption  \
# 0                       2                 High                             30
# ...

# %% [markdown]
# Proses pembuatan data untuk kebutuhan inferencing

# %%
# Test prediksi repeat buyer
pred = best_model.predict(data)

# Memasukkan ke dalam dataframe awal
data['Rating'] = pred

# Menampilkan hasil inference
data
# Out:
#    Age  Location             DietType LocalFoodFrequency TransportationMode  \
# 0   20     Rural  Mostly Animal-Based              Often                Car
# 1   24  Suburban   Mostly Plant-Based          Sometimes               Bike
# 2   35     Rural   Mostly Plant-Based          Sometimes               Walk
# 3   46     Urban             Balanced             Rarely     Public Transit
#
#     EnergySource   HomeType  HomeSize ClothingFrequency  SustainableBrands  \
# 0          Mixed      House       300            Rarely              False
# 1      Renewable      House       456             Often               True
# 2      Renewable      House       900         Sometimes              False
# 3  Non-Renewable  Apartment      3000            Rarely              False
#
#    EnvironmentalAwareness CommunityInvolvement  MonthlyElectricityConsumption  \
# 0                       2                 High                             30
# ...

# %% [markdown]
# Hasil inference menunjukan data yang diinput mendapat `Rating` tingkat kehidupan sustainable dari Poor hingga Very Good
